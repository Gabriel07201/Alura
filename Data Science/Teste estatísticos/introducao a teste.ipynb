# %%
import pandas as pd

# %%
tmdb = pd.read_csv(r'C:\Users\Gabriel\Desktop\Programação\Alura\Data Science\Teste estatísticos\dados\tmdb_5000_movies.csv')

# %%
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import seaborn as sns
ax = sns.distplot(tmdb['vote_average'])
ax.set(xlabel='Nota média', ylabel='Densidade', title='Média de votos no tmdb')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\105436217.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb['vote_average'])
# [Text(0.5, 0, 'Nota média'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Média de votos no tmdb')]

# %%
import seaborn as sns
ax = sns.distplot(tmdb['vote_average'], norm_hist=False, kde=False)
ax.set(xlabel='Nota média', ylabel='Densidade', title='Média de votos no tmdb')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1571080650.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb['vote_average'], norm_hist=False, kde=False)
# [Text(0.5, 0, 'Nota média'),
#  Text(0, 0.5, 'Densidade'),
#  Text(0.5, 1.0, 'Média de votos no tmdb')]

# %%
ax = sns.boxplot(tmdb['vote_average'], orient='h')
ax.set_title('Distribuição de nota média dos filmes')
ax.set_xlabel('Nota média do filme')
# Out:
# Text(0.5, 0, 'Nota média do filme')

# %% [markdown]
# Não faz sentido existir filmes cuja a nota média seja 0 ou 10. Por isso é verificado logo abaixo.

# %%
tmdb.query('vote_average == 0')
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# ...

# %%
tmdb_com_mais_de_10_votos = tmdb.query('vote_count >=10')
tmdb_com_mais_de_10_votos.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %% [markdown]
# Os filmes tiveram poucos ou nenhum votos. Por isso eles serão retirados da análise.

# %%
ax = sns.distplot(tmdb_com_mais_de_10_votos['vote_average'], norm_hist=False, kde=False)
ax.set_title('Média de votos em filmes com 10 ou mais votos')
ax.set(xlabel='Nota média', ylabel='Frequência')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1556190918.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_de_10_votos['vote_average'], norm_hist=False, kde=False)
# [Text(0.5, 0, 'Nota média'), Text(0, 0.5, 'Frequência')]

# %%
ax = sns.distplot(tmdb_com_mais_de_10_votos['vote_average'])
ax.set_title('Média de votos em filmes com 10 ou mais votos')
ax.set(xlabel='Nota média', ylabel='Densidade')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1167462657.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_de_10_votos['vote_average'])
# [Text(0.5, 0, 'Nota média'), Text(0, 0.5, 'Densidade')]

# %%
ax = sns.boxplot(tmdb_com_mais_de_10_votos['vote_average'], orient='h')
ax.set_title('Histograma de nota média dos filmes com 10 ou mais votos')
ax.set_xlabel('Nota média do filme')
# Out:
# Text(0.5, 0, 'Nota média do filme')

# %% [markdown]
# # Analizando os dados também de outra base de filmes

# %%
notas = pd.read_csv(r'C:\Users\Gabriel\Desktop\Programação\Alura\Data Science\Teste estatísticos\dados\ratings.csv')
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
nota_media_por_filme = notas.groupby('movieId').mean()['rating']
nota_media_por_filme
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
ax = sns.distplot(nota_media_por_filme.values)
ax.set_title('Média de votos em filmes')
ax.set(xlabel='Nota média', ylabel='Densidade')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1598804090.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_por_filme.values)
# [Text(0.5, 0, 'Nota média'), Text(0, 0.5, 'Densidade')]

# %%
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
quantidade_de_votos_por_filme = notas.groupby('movieId').count()
filme_com_pelo_menos_10_votos = quantidade_de_votos_por_filme.query('rating >=10').index
filme_com_pelo_menos_10_votos.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593], dtype=int64)

# %%
nota_media_por_filme_com_pelo_menos_10_votos = nota_media_por_filme.loc[filme_com_pelo_menos_10_votos.values]
nota_media_por_filme_com_pelo_menos_10_votos.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 5    3.071429
# 6    3.946078
# Name: rating, dtype: float64

# %%
ax = sns.distplot(nota_media_por_filme_com_pelo_menos_10_votos.values)
ax.set_title('Média de votos em filmes com 10 ou mais votos')
ax.set(xlabel='Nota média', ylabel='Densidade')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1758449110.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_por_filme_com_pelo_menos_10_votos.values)
# [Text(0.5, 0, 'Nota média'), Text(0, 0.5, 'Densidade')]

# %%
ax = sns.boxplot(nota_media_por_filme_com_pelo_menos_10_votos.values, orient='h')
ax.set_title('Histograma de nota média dos filmes com 10 ou mais votos')
ax.set_xlabel('Nota média do filme')
# Out:
# Text(0.5, 0, 'Nota média do filme')

# %%
ax = sns.distplot(nota_media_por_filme_com_pelo_menos_10_votos.values, hist_kws={'cumulative':True}, kde_kws={'cumulative':True})
ax.set_title('Média de votos em filmes com 10 ou mais votos')
ax.set(xlabel='Nota média', ylabel='% Acumulada de filmes')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1049078178.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_por_filme_com_pelo_menos_10_votos.values, hist_kws={'cumulative':True}, kde_kws={'cumulative':True})
# [Text(0.5, 0, 'Nota média'), Text(0, 0.5, '% Acumulada de filmes')]

# %% [markdown]
# # Analizando a distribuição de outros campos

# %%
tmdb_com_mais_de_10_votos['vote_count']
# Out:
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124
#         ...
# 4790       17
# 4792       63
# 4796      658
# 4798      238
# 4802       16
# Name: vote_count, Length: 4392, dtype: int64

# %%
ax = sns.distplot(tmdb_com_mais_de_10_votos['vote_count'])
ax.set_title('Número de votos em filmes com 10 ou mais votos')
ax.set(xlabel='Número de votos', ylabel='Densidade')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\2702918.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_de_10_votos['vote_count'])
# [Text(0.5, 0, 'Número de votos'), Text(0, 0.5, 'Densidade')]

# %%
ax = sns.distplot(tmdb.query('budget > 0')['budget'])
ax.set_title('Gastos em filmes')
ax.set(xlabel='Budget (gastos)', ylabel='Densidade')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\3355649417.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query('budget > 0')['budget'])
# [Text(0.5, 0, 'Budget (gastos)'), Text(0, 0.5, 'Densidade')]

# %%
tmdb.query('popularity ==0')
# Out:
#       budget genres homepage      id keywords original_language  \
# 4553       0     []      NaN  380097       []                en
#
#                   original_title  \
# 4553  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      production_companies production_countries release_date  revenue  runtime  \
# 4553                   []                   []          NaN        0      0.0
#
#      spoken_languages    status tagline                       title  \
# 4553               []  Released     NaN  America Is Still the Place
#
#       vote_average  vote_count
# 4553           0.0           0

# %%
ax = sns.distplot(tmdb['popularity'])
ax.set_title('Popularidade')
ax.set(xlabel='Popularidade', ylabel='Densidade')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\2813140109.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb['popularity'])
# [Text(0.5, 0, 'Popularidade'), Text(0, 0.5, 'Densidade')]

# %%
tmdb['runtime']
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4803, dtype: float64

# %%
tmdb['runtime'].isnull().sum()
# Out:
# 2

# %%
tmdb['runtime'].dropna()
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4801, dtype: float64

# %%
ax = sns.distplot(tmdb['runtime'].dropna())
ax.set_title('Popularidade')
ax.set(xlabel='Popularidade', ylabel='Densidade')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1129160652.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb['runtime'].dropna())
# [Text(0.5, 0, 'Popularidade'), Text(0, 0.5, 'Densidade')]

# %%
ax = sns.distplot(tmdb.query('runtime > 0')['runtime'].dropna())
ax.set_title('Duração')
ax.set(xlabel='Tempo de duração', ylabel='Densidade')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1274459175.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query('runtime > 0')['runtime'].dropna())
# [Text(0.5, 0, 'Tempo de duração'), Text(0, 0.5, 'Densidade')]

# %%
tmdb.query('runtime > 0')['runtime'].dropna().quantile(0.8)
# Out:
# 121.0

# %% [markdown]
# # Movielens: média dos filmes com pelo menos 10 votos

# %%
print(f'Média dos filmes com pelo menos 10 votos: {nota_media_por_filme_com_pelo_menos_10_votos.mean()}')
# Out:
# Média dos filmes com pelo menos 10 votos: 3.4320503405352594

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(75243)
temp = nota_media_por_filme_com_pelo_menos_10_votos.sample(frac=1)

medias = list()
for i in range(1 ,len(nota_media_por_filme_com_pelo_menos_10_votos)):
    medias.append(nota_media_por_filme_com_pelo_menos_10_votos[0:i].mean())

plt.plot(medias)
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1293628086.py:9: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   medias.append(nota_media_por_filme_com_pelo_menos_10_votos[0:i].mean())

# %%
np.random.seed(75243)
temp = nota_media_por_filme_com_pelo_menos_10_votos.sample(frac=1)

medias = list()
for i in range(1 ,len(temp)):
    medias.append(temp[0:i].mean())

plt.plot(medias)
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1142429104.py:6: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   medias.append(temp[0:i].mean())

# %%
from statsmodels.stats.weightstats import zconfint, DescrStatsW
zconfint(nota_media_por_filme_com_pelo_menos_10_votos)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
desc_todos_com_10_votos = DescrStatsW(nota_media_por_filme_com_pelo_menos_10_votos)

# %%
desc_todos_com_10_votos.tconfint_mean()
# Out:
# (3.411234839229381, 3.4528658418411395)

# %% [markdown]
# # Comparando médias

# %%
filmes = pd.read_csv(r'C:\Users\Gabriel\Desktop\Programação\Alura\Data Science\Teste estatísticos\dados\movies.csv')
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas1 = notas.query('movieId ==1')
notas1.head()
# Out:
#       userId  movieId  rating   timestamp
# 0          1        1     4.0   964982703
# 516        5        1     4.0   847434962
# 874        7        1     4.5  1106635946
# 1434      15        1     2.5  1510577970
# 1667      17        1     4.5  1305696483

# %%
ax = sns.distplot(notas1['rating'])
ax.set_title('Notas para o ToyStory')
ax.set(xlabel='Notas', ylabel='Densidade')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1474062800.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(notas1['rating'])
# [Text(0.5, 0, 'Notas'), Text(0, 0.5, 'Densidade')]

# %%
ax = sns.boxplot(notas1['rating'], orient='h')
ax.set_title('Histograma de nota ToyStory')
ax.set_xlabel('Nota do filme')
# Out:
# Text(0.5, 0, 'Nota do filme')

# %%
notas1['rating'].mean()
# Out:
# 3.9209302325581397

# %%
zconfint(notas1['rating'])
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
np.random.seed(75241)
temp = notas1['rating'].sample(frac=1)

medias = list()
for i in range(1 ,len(temp)):
    medias.append(temp[0:i].mean())


plt.plot(medias)
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1861883876.py:6: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   medias.append(temp[0:i].mean())

# %%
from statsmodels.stats.weightstats import ztest

np.random.seed(75241)
temp = notas1.sample(frac=1).rating

valores = list()
for i in range(2 ,len(temp)):
    # medias.append(temp[0:i].mean())
    media = temp[0:i].mean()
    stat, p = ztest(temp[0:i], value= 3.4320503405352594)
    # print(i, media, p)
    valores.append([i, media, p])
valores = np.array(valores)
plt.plot(valores[:,0], valores[:,1])
plt.plot(valores[:,0], valores[:,2])
plt.hlines(y=0.05, xmin=2, xmax=len(temp), color='red')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1307939830.py:9: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   media = temp[0:i].mean()
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_4312\1307939830.py:10: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   stat, p = ztest(temp[0:i], value= 3.4320503405352594)

# %%
zconfint(notas1['rating'], notas['rating'])
# Out:
# (0.2799245129192442, 0.5588219849631111)

# %%
from scipy.stats import ttest_ind

ttest_ind(notas['rating'], notas1['rating'])
# Out:
# Ttest_indResult(statistic=-5.894327101501841, pvalue=3.774003138720876e-09)

# %%
desc_todas_as_notas = DescrStatsW(notas['rating'])
desc_toystory = DescrStatsW(notas1['rating'])
comparacao = desc_todas_as_notas.get_compare(desc_toystory)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
import matplotlib.pyplot as plt

plt.boxplot([notas['rating'], notas1['rating']], labels=['Todas as notas', 'Toy Story'])
plt.title('Distribuição das notas de acordo com filmes')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas de acordo com filmes')

# %% [markdown]
# # Comparando a média de 2 filmes

# %%
filmes.query('movieId in [1, 593, 72226]')
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas593 = notas.query('movieId == 593')
notas72226 = notas.query('movieId == 72226')
notas1 = notas.query('movieId == 1')

plt.boxplot([notas1.rating, notas72226.rating, notas593.rating], labels=['Toy Story', 'The silence of the lambs', 'Fantastic Mr. FOx'])
plt.title('Distribuição das notas de acordo com filmes')
plt.grid()

# %%
notas.query('movieId in [1, 593, 72226]').groupby('movieId').count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
desc_1 = DescrStatsW(notas1['rating'])
desc_593 = DescrStatsW(notas593['rating'])
comparacao_1_e_593 = desc_1.get_compare(desc_593)
comparacao_1_e_593.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
desc_72226 = DescrStatsW(notas72226['rating'])
comparacao_593_e_72226 = desc_72226.get_compare(desc_593)
comparacao_593_e_72226.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
from scipy.stats import normaltest, ranksums

_, p = normaltest(notas1.rating)
print(p)
# Out:
# 0.00011053430732728716

# %%
_, p  = ranksums(notas1.rating, notas593.rating)
print(p)
# Out:
# 0.0003267718756440693
